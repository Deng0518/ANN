# %% [markdown]
# <a href="https://colab.research.google.com/github/Deng0518/ANN/blob/main/Meta(Timeseries_Forecast)_DNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Basic packages always been used
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Data scaling
from sklearn.preprocessing import MinMaxScaler

# Function for spilting training & testing data set
from sklearn.model_selection import train_test_split

# Tensorflow sequential models
from tensorflow import keras
from keras import backend as clear
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import BatchNormalization
from keras.optimizers import SGD
from keras.optimizers import Adam

# Functions for evaluation
from sklearn.metrics import mean_absolute_error #MAE
from sklearn.metrics import mean_squared_error #MSE,RMSE
from sklearn.metrics import mean_absolute_percentage_error #MAPE

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Note: Some metrics need to be defined manually

# %%
# Symmetric Mean Absolute Percentage Error (SMAPE)
def SMAPE_calulate(y_true, y_pred):
    n = len(y_true)
    SMAPE=(100 / n) * np.sum(2 * np.abs(y_pred - y_true) / (np.abs(y_pred) + np.abs(y_true)))
    return SMAPE

# Relative Absolute Error (RAE)
def RAE_calculate(y_true, y_pred):
    abs_errors = np.abs(y_true - y_pred)
    denominator = np.sum(np.abs(y_true - np.mean(y_true)))
    RAE=np.sum(abs_errors/denominator)
    return RAE

# Mean Relative Absolute Error (MRAE)
def MRAE_calculate(y_true, y_pred):
    n=len(y_true)
    abs_errors = np.abs(y_true - y_pred)
    denominator = np.sum(np.abs(y_true - np.mean(y_true)))
    RAE=np.sum(abs_errors/denominator)
    MRAE=RAE/n
    return MRAE

# Median Relative Absolute Error (MdRAE) comparing with benchmark
# Note: By default, the bench value is the mean of actual value
def MdRAE_calculate(y_true, y_pred, bench=None):
    if bench==None:
        bench=np.mean(y_true)
        MdRAE=np.median(np.abs(y_true - y_pred)/np.abs(y_true - bench))
        return MdRAE,bench
    else:
        MdRAE=np.median(np.abs(y_true - y_pred)/np.abs(y_true - bench))
        return MdRAE
    
# Relative Squared Error (RSE) & Root Relative Squared Error (RRSE)
def RSE_calculate(y_true, y_pred, Root=False):
    mse = np.mean((y_true - y_pred)**2)
    denominator = np.var(y_true)
    RSE=mse/denominator
    
    if Root==True:
        return np.sqrt(RSE)
    else:
        return RSE

# %%
#load data(sometimes need to use "/")
#df = pd.read_csv('D:/ANN_Timeseries_Forecast_python_demo/Data/Rainfall_Forecast.csv')
# Colab
df = pd.read_csv('/content/drive/MyDrive/META.csv')
df

# %% [markdown]
# # 1. Preparations for time-series data

# %% [markdown]
# Note: Pandas has a specific data type for time-series data

# %%
# Date is converted into special data type of pandas
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1510 entries, 0 to 1509
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1510 non-null   object
#  1   Open       1510 non-null   float64
#  2   High       1510 non-null   float64
#  3   Low        1510 non-null   float64
#  4   Close      1510 non-null   float64
#  5   Adj Close  1510 non-null   float64
#  6   Volume     1510 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 82.7+ KB

# %%
new_df=df.iloc[:,[0,4]].copy()
new_df.head()
# Out:
#          Date       Close
# 0  2017-05-23  148.070007
# 1  2017-05-24  150.039993
# 2  2017-05-25  151.960007
# 3  2017-05-26  152.130005
# 4  2017-05-30  152.380005

# %%
# View descriptive statistics of target variable
# Pandas will automatically ignore date if the correct data type has been converted
new_df.describe()
# Out:
#              Close
# count  1510.000000
# mean    211.076563
# std      63.832345
# min      88.910004
# 25%     168.832501
# 50%     188.480003
# 75%     249.094997
# max     382.179993

# %%
# Plot Y and its corresponding date
# Figure setting
plt.figure(figsize=(24,8),dpi=300)
plt.title('Closing Price of Meta Platforms, Inc. between May 23rd, 2020 & May 22nd, 2023',weight='bold',fontsize=24)
plt.xlabel('Date',fontsize=18,weight='bold')
plt.ylabel('Close',fontsize=18,weight='bold')

# Actual by predicted plot
plt.plot(new_df['Date'],new_df['Close'],marker='.',color='blue')

# Set the axis
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# # 2. Creating time lags as predictor variables

# %% [markdown]
# # Important!: Be caution when dealing with time-series data

# %% [markdown]
# python do have various packages and function that can deal with time-series data with ease, however, make sure that you understand the fundamental first!

# %%
# Create 3 lags
new_df['Lag_1']=new_df['Close'].shift(1).copy()
new_df['Lag_2']=new_df['Close'].shift(2).copy()
new_df['Lag_3']=new_df['Close'].shift(3).copy()
new_df.head()
# Out:
#          Date       Close       Lag_1       Lag_2       Lag_3
# 0  2017-05-23  148.070007         NaN         NaN         NaN
# 1  2017-05-24  150.039993  148.070007         NaN         NaN
# 2  2017-05-25  151.960007  150.039993  148.070007         NaN
# 3  2017-05-26  152.130005  151.960007  150.039993  148.070007
# 4  2017-05-30  152.380005  152.130005  151.960007  150.039993

# %%
# Drop out missing values and rest index
clean_df=new_df.dropna(axis=0, how='any').copy()
clean_df=clean_df.reset_index(drop=True)
clean_df
# Out:
#             Date       Close       Lag_1       Lag_2       Lag_3
# 0     2017-05-26  152.130005  151.960007  150.039993  148.070007
# 1     2017-05-30  152.380005  152.130005  151.960007  150.039993
# 2     2017-05-31  151.460007  152.380005  152.130005  151.960007
# 3     2017-06-01  151.529999  151.460007  152.380005  152.130005
# 4     2017-06-02  153.610001  151.529999  151.460007  152.380005
# ...          ...         ...         ...         ...         ...
# 1502  2023-05-16  238.820007  238.860001  233.809998  235.789993
# 1503  2023-05-17  242.490005  238.820007  238.860001  233.809998
# 1504  2023-05-18  246.850006  242.490005  238.820007  238.860001
# 1505  2023-05-19  245.639999  246.850006  242.490005  238.820007
# 1506  2023-05-22  248.320007  245.639999  246.850006  242.490005
#
# [1507 rows x 5 columns]

# %%
# Colab
clean_df.to_csv('Meta_Lags.csv',index=False, header=True)

# %% [markdown]
# # 3. Data preprocessing under time-series structure

# %% [markdown]
# A total of 6 years are in the data set. In this practice, we will use the last one years of data as the testing set

# %%
# Train data
Forecast_train_data=clean_df.iloc[0:1257,:].copy()
Forecast_train_data
# Out:
#             Date       Close       Lag_1       Lag_2       Lag_3
# 0     2017-05-26  152.130005  151.960007  150.039993  148.070007
# 1     2017-05-30  152.380005  152.130005  151.960007  150.039993
# 2     2017-05-31  151.460007  152.380005  152.130005  151.960007
# 3     2017-06-01  151.529999  151.460007  152.380005  152.130005
# 4     2017-06-02  153.610001  151.529999  151.460007  152.380005
# ...          ...         ...         ...         ...         ...
# 1252  2022-05-17  202.619995  200.039993  198.619995  191.240005
# 1253  2022-05-18  192.240005  202.619995  200.039993  198.619995
# 1254  2022-05-19  191.289993  192.240005  202.619995  200.039993
# 1255  2022-05-20  193.539993  191.289993  192.240005  202.619995
# 1256  2022-05-23  196.229996  193.539993  191.289993  192.240005
#
# [1257 rows x 5 columns]

# %%
# Test data
Forecast_test_data=clean_df.iloc[1257:1257+250,:].copy()
Forecast_test_data
# Out:
#             Date       Close       Lag_1       Lag_2       Lag_3
# 1257  2022-05-24  181.279999  196.229996  193.539993  191.289993
# 1258  2022-05-25  183.830002  181.279999  196.229996  193.539993
# 1259  2022-05-26  191.630005  183.830002  181.279999  196.229996
# 1260  2022-05-27  195.130005  191.630005  183.830002  181.279999
# 1261  2022-05-31  193.639999  195.130005  191.630005  183.830002
# ...          ...         ...         ...         ...         ...
# 1502  2023-05-16  238.820007  238.860001  233.809998  235.789993
# 1503  2023-05-17  242.490005  238.820007  238.860001  233.809998
# 1504  2023-05-18  246.850006  242.490005  238.820007  238.860001
# 1505  2023-05-19  245.639999  246.850006  242.490005  238.820007
# 1506  2023-05-22  248.320007  245.639999  246.850006  242.490005
#
# [250 rows x 5 columns]

# %% [markdown]
# # 4. Prepare time-series data for train/validation structure manually

# %% [markdown]
# Here we have a total of 18 years of data in training data set that are ready to be further splitted into training and validation data set

# %% [markdown]
# 18 years of data can be evenlly divided into 6 portions (3 years in each portion)

# %% [markdown]
# # Expanding window

# %%
# Expanding 1
Exp_training_1=Forecast_train_data.iloc[0:627,:].copy()
Exp_val_1=Forecast_train_data.iloc[627:627+210,:].copy()

# Expanding 2
Exp_training_2=Forecast_train_data.iloc[0:837,:].copy()
Exp_val_2=Forecast_train_data.iloc[837:837+210,:].copy()

# Expanding 3
Exp_training_3=Forecast_train_data.iloc[0:1047,:].copy()
Exp_val_3=Forecast_train_data.iloc[1047:1047+210,:].copy()

# %% [markdown]
# # Rolling window

# %%
# Rolling 1
Rol_training_1=Forecast_train_data.iloc[0:627,:].copy()
Rol_val_1=Forecast_train_data.iloc[627:627+210,:].copy()

# Rolling 2
Rol_training_2=Forecast_train_data.iloc[207:837,:].copy()
Rol_val_2=Forecast_train_data.iloc[837:837+210,:].copy()

# Rolling 3
Rol_training_3=Forecast_train_data.iloc[417:1047,:].copy()
Rol_val_3=Forecast_train_data.iloc[1047:1047+210,:].copy()

# %% [markdown]
# # 5. Set dependent variable(Y or target) & independent variable(X)

# %%
#set x (make prediction)
# Train
x_train=Exp_training_3.drop(['Date','Close'],axis=1).copy()
#minimax scaling
MMscaler=MinMaxScaler(feature_range=(0, 1))
scalingT=MMscaler.fit_transform(x_train)
scaled_x_train=pd.DataFrame(data=scalingT)
scaled_x_train.columns=['Lag_1','Lag_2','Lag_3']

# Validation
x_val=Exp_val_3.drop(['Date','Close'],axis=1).copy()
#minimax scaling
MMscaler=MinMaxScaler(feature_range=(0, 1))
scalingV=MMscaler.fit_transform(x_val)
scaled_x_val=pd.DataFrame(data=scalingV)
scaled_x_val.columns=['Lag_1','Lag_2','Lag_3']

#set y (want to predict)
y_train=Exp_training_3['Close'].copy()
y_val=Exp_val_3['Close'].copy()

# %%
#set x (make prediction)
# Train
x_train=Rol_training_1.drop(['Date','Close'],axis=1).copy()
#minimax scaling
MMscaler=MinMaxScaler(feature_range=(0, 1))
scalingT=MMscaler.fit_transform(x_train)
scaled_x_train=pd.DataFrame(data=scalingT)
scaled_x_train.columns=['Lag_1','Lag_2','Lag_3']

# Validation
x_val=Rol_val_1.drop(['Date','Close'],axis=1).copy()
#minimax scaling
MMscaler=MinMaxScaler(feature_range=(0, 1))
scalingV=MMscaler.fit_transform(x_val)
scaled_x_val=pd.DataFrame(data=scalingV)
scaled_x_val.columns=['Lag_1','Lag_2','Lag_3']

#set y (want to predict)
y_train=Rol_training_1['Close'].copy()
y_val=Rol_val_1['Close'].copy()

# %% [markdown]
# # 6. Creating Net

# %%
# Quick recap: Total of 12 features in the data set
scaled_x_train.head()
# Out:
#       Lag_1     Lag_2     Lag_3
# 0  0.120477  0.112186  0.103679
# 1  0.121211  0.120477  0.112186
# 2  0.122290  0.121211  0.120477
# 3  0.118318  0.122290  0.121211
# 4  0.118620  0.118318  0.122290

# %%
# Tips: Using shape to call the amount of features in the data set 
input_features=scaled_x_train.shape[1]
print('Amount of features:',input_features)
# Out:
# Amount of features: 3

# %% [markdown]
# # Important: Define customized loss function (RMSE)

# %%
from keras.losses import mse
from keras.backend import sqrt

def my_RMSE(y_true, y_pred):
    return sqrt(mse(y_true, y_pred))

# Register custom object
#from keras.utils.generic_utils import get_custom_objects for pc
from tensorflow.keras.saving import get_custom_objects
get_custom_objects().update({'my_RMSE': my_RMSE})

# %% [markdown]
# Note: As far as I know when I'm preparing this in-class material, keras does not have a built-in RMSE function. Rumor has it that a RMSE function is hidden in the latest version, however it needs to be confirmed. For instance, defining RMSE ourself is not difficult, just don't forget to register our custom functions.

# %%
# Some self define functions for building deep neural networks
def dense_generator(model_name,layers,last_layer_neurons,activation_fun='relu'):
    n=last_layer_neurons
    neurons=n
    for i in range(0,layers):
        neurons=neurons*2
        model_name.add(Dense(units=neurons, activation=activation_fun))

# %% [markdown]
# # Sequential style coding for creating net

# %%
# 6.1 Create the model
clear.clear_session()
model=Sequential()

# 6.2 Add input layer & first hidden layer
model.add(Dense(units=6, input_dim=3, activation='relu'))

# 6.3 Add 5 dense layers
dense_generator(model,5,6)

# Add dropout layer
model.add(Dropout(rate=0.2))

# Add 2 more dense layers
dense_generator(model,2,192)

# 6.5 Add output layer
model.add(Dense(units=1, activation='linear'))

# 6.6 Compile the defined Net
#opt=SGD(learning_rate=0.001,momentum=0.5)
opt=Adam(learning_rate=0.01,beta_1=0.8)
model.compile(loss='my_RMSE', optimizer=opt, metrics=['mean_absolute_percentage_error'])

# Finally check the model 
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 6)                 24
#
#  dense_1 (Dense)             (None, 12)                84
#
#  dense_2 (Dense)             (None, 24)                312
#
#  dense_3 (Dense)             (None, 48)                1200
#
#  dense_4 (Dense)             (None, 96)                4704
#
#  dense_5 (Dense)             (None, 192)               18624
#
#  dropout (Dropout)           (None, 192)               0
#
#  dense_6 (Dense)             (None, 384)               74112
#
#  dense_7 (Dense)             (None, 768)               295680
#
#  dense_8 (Dense)             (None, 1)                 769
#
# =================================================================
# Total params: 395,509
# Trainable params: 395,509
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Note: Remember to clear the session or else some of the left neurans may cause trouble while fitting

# %% [markdown]
# # 7. Fit the model (train/validation)

# %%
# 7.1 Store in the history for more useful information
history=model.fit(scaled_x_train, y_train, epochs=200, batch_size=64,verbose=1,validation_data=(scaled_x_val, y_val))
# Out:
# Epoch 1/200
# 17/17 [==============================] - 1s 19ms/step - loss: 171.7990 - mean_absolute_percentage_error: 83.0199 - val_loss: 175.5604 - val_mean_absolute_percentage_error: 59.8364
# Epoch 2/200
# 17/17 [==============================] - 0s 7ms/step - loss: 33.9595 - mean_absolute_percentage_error: 16.4032 - val_loss: 16.6728 - val_mean_absolute_percentage_error: 6.4604
# Epoch 3/200
# 17/17 [==============================] - 0s 6ms/step - loss: 13.6371 - mean_absolute_percentage_error: 6.5290 - val_loss: 56.8530 - val_mean_absolute_percentage_error: 20.5030
# Epoch 4/200
# 17/17 [==============================] - 0s 6ms/step - loss: 15.5253 - mean_absolute_percentage_error: 7.4758 - val_loss: 36.9701 - val_mean_absolute_percentage_error: 13.9269
# Epoch 5/200
# 17/17 [==============================] - 0s 5ms/step - loss: 14.4327 - mean_absolute_percentage_error: 6.9520 - val_loss: 79.7602 - val_mean_absolute_percentage_error: 28.0965
# Epoch 6/200
# 17/17 [==============================] - 0s 5ms/step - loss: 27.1704 - mean_absolute_percentage_error: 13.1247 - val_loss: 36.3604 - val_mean_absolute_percentage_error: 13.2539
# Epoch 7/200
# 17/17 [==============================] - 0s 5ms/step - loss: 17.6471 - mean_absolute_percentage_error: 8.4524 - val_loss: 20.0655 - val_mean_absolute_percentage_error: 7.9723
# Epoch 8/200
# 17/17 [==============================] - 0s 5ms/step - loss: 11.6798 - mean_absolute_percentage_error: 5.5871 - val_loss: 47.9887 - val_mean_absolute_percentage_error: 17.3849
# Epoch 9/200
# 17/17 [==============================] - 0s 6ms/step - loss: 10.3800 - mean_absolute_percentage_error: 4.9081 - val_loss: 32.3908 - val_mean_absolute_percentage_error: 12.5227
# Epoch 10/200
# 17/17 [==============================] - 0s 6ms/step - loss: 11.4231 - mean_absolute_percentage_error: 5.4462 - val_loss: 53.7618 - val_mean_absolute_percentage_error: 19.3188
# Epoch 11/200
# 17/17 [==============================] - 0s 7ms/step - loss: 22.8403 - mean_absolute_percentage_error: 10.9295 - val_loss: 42.6104 - val_mean_absolute_percentage_error: 15.2765
# Epoch 12/200
# 17/17 [==============================] - 0s 6ms/step - loss: 10.2882 - mean_absolute_percentage_error: 5.0013 - val_loss: 38.1863 - val_mean_absolute_percentage_error: 14.2916
# Epoch 13/200
# 17/17 [==============================] - 0s 5ms/step - loss: 11.9963 - mean_absolute_percentage_error: 5.8006 - val_loss: 42.2529 - val_mean_absolute_percentage_error: 15.7576
# Epoch 14/200
# 17/17 [==============================] - 0s 5ms/step - loss: 19.1181 - mean_absolute_percentage_error: 9.0187 - val_loss: 24.0526 - val_mean_absolute_percentage_error: 9.3458
# Epoch 15/200
# 17/17 [==============================] - 0s 6ms/step - loss: 10.8543 - mean_absolute_percentage_error: 5.2846 - val_loss: 37.5206 - val_mean_absolute_percentage_error: 13.8544
# Epoch 16/200
# 17/17 [==============================] - 0s 6ms/step - loss: 8.9908 - mean_absolute_percentage_error: 4.3546 - val_loss: 33.9374 - val_mean_absolute_percentage_error: 13.1216
# Epoch 17/200
# 17/17 [==============================] - 0s 6ms/step - loss: 10.2702 - mean_absolute_percentage_error: 4.9264 - val_loss: 28.0244 - val_mean_absolute_percentage_error: 10.8390
# Epoch 18/200
# 17/17 [==============================] - 0s 5ms/step - loss: 8.1921 - mean_absolute_percentage_error: 3.9241 - val_loss: 37.6985 - val_mean_absolute_percentage_error: 14.4913
# Epoch 19/200
# 17/17 [==============================] - 0s 9ms/step - loss: 12.5821 - mean_absolute_percentage_error: 6.0056 - val_loss: 81.7659 - val_mean_absolute_percentage_error: 27.6554
# Epoch 20/200
# 17/17 [==============================] - 0s 9ms/step - loss: 13.9190 - mean_absolute_percentage_error: 6.7489 - val_loss: 18.9962 - val_mean_absolute_percentage_error: 7.8200
# Epoch 21/200
# 17/17 [==============================] - 0s 8ms/step - loss: 9.1187 - mean_absolute_percentage_error: 4.3159 - val_loss: 32.9999 - val_mean_absolute_percentage_error: 12.6084
# Epoch 22/200
# 17/17 [==============================] - 0s 8ms/step - loss: 8.1779 - mean_absolute_percentage_error: 3.8702 - val_loss: 40.2033 - val_mean_absolute_percentage_error: 14.8188
# Epoch 23/200
# 17/17 [==============================] - 0s 8ms/step - loss: 8.8798 - mean_absolute_percentage_error: 4.2084 - val_loss: 37.5387 - val_mean_absolute_percentage_error: 14.4721
# Epoch 24/200
# 17/17 [==============================] - 0s 8ms/step - loss: 9.8680 - mean_absolute_percentage_error: 4.6748 - val_loss: 40.5718 - val_mean_absolute_percentage_error: 15.3811
# Epoch 25/200
# 17/17 [==============================] - 0s 7ms/step - loss: 7.7666 - mean_absolute_percentage_error: 3.6799 - val_loss: 42.9300 - val_mean_absolute_percentage_error: 15.7468
# Epoch 26/200
# 17/17 [==============================] - 0s 7ms/step - loss: 7.0259 - mean_absolute_percentage_error: 3.2964 - val_loss: 52.7296 - val_mean_absolute_percentage_error: 18.8412
# Epoch 27/200
# 17/17 [==============================] - 0s 8ms/step - loss: 8.3398 - mean_absolute_percentage_error: 3.9562 - val_loss: 28.7006 - val_mean_absolute_percentage_error: 11.0827
# Epoch 28/200
# 17/17 [==============================] - 0s 8ms/step - loss: 8.2371 - mean_absolute_percentage_error: 3.8690 - val_loss: 29.4808 - val_mean_absolute_percentage_error: 11.6448
# Epoch 29/200
# 17/17 [==============================] - 0s 8ms/step - loss: 8.5177 - mean_absolute_percentage_error: 3.9897 - val_loss: 40.8822 - val_mean_absolute_percentage_error: 15.0959
# Epoch 30/200
# 17/17 [==============================] - 0s 8ms/step - loss: 6.8518 - mean_absolute_percentage_error: 3.2773 - val_loss: 37.2971 - val_mean_absolute_percentage_error: 14.4783
# Epoch 31/200
# 17/17 [==============================] - 0s 9ms/step - loss: 8.8135 - mean_absolute_percentage_error: 4.1711 - val_loss: 37.5836 - val_mean_absolute_percentage_error: 14.0084
# Epoch 32/200
# 17/17 [==============================] - 0s 8ms/step - loss: 13.7454 - mean_absolute_percentage_error: 6.4647 - val_loss: 29.5797 - val_mean_absolute_percentage_error: 10.0979
# Epoch 33/200
# 17/17 [==============================] - 0s 7ms/step - loss: 14.3138 - mean_absolute_percentage_error: 6.7815 - val_loss: 28.0949 - val_mean_absolute_percentage_error: 11.2941
# Epoch 34/200
# 17/17 [==============================] - 0s 8ms/step - loss: 9.0214 - mean_absolute_percentage_error: 4.2652 - val_loss: 26.9581 - val_mean_absolute_percentage_error: 10.3384
# Epoch 35/200
# 17/17 [==============================] - 0s 8ms/step - loss: 9.8966 - mean_absolute_percentage_error: 4.7165 - val_loss: 30.4619 - val_mean_absolute_percentage_error: 11.8434
# Epoch 36/200
# 17/17 [==============================] - 0s 7ms/step - loss: 7.6943 - mean_absolute_percentage_error: 3.6709 - val_loss: 45.1103 - val_mean_absolute_percentage_error: 16.4435
# Epoch 37/200
# 17/17 [==============================] - 0s 8ms/step - loss: 13.0516 - mean_absolute_percentage_error: 6.1062 - val_loss: 44.8937 - val_mean_absolute_percentage_error: 16.1612
# Epoch 38/200
# 17/17 [==============================] - 0s 8ms/step - loss: 11.9233 - mean_absolute_percentage_error: 5.6404 - val_loss: 62.2634 - val_mean_absolute_percentage_error: 21.6715
# Epoch 39/200
# 17/17 [==============================] - 0s 7ms/step - loss: 10.2390 - mean_absolute_percentage_error: 4.8960 - val_loss: 33.9594 - val_mean_absolute_percentage_error: 12.9238
# Epoch 40/200
# 17/17 [==============================] - 0s 8ms/step - loss: 6.6221 - mean_absolute_percentage_error: 3.1882 - val_loss: 21.5914 - val_mean_absolute_percentage_error: 9.0609
# Epoch 41/200
# 17/17 [==============================] - 0s 7ms/step - loss: 8.6770 - mean_absolute_percentage_error: 4.0790 - val_loss: 54.3451 - val_mean_absolute_percentage_error: 19.1255
# Epoch 42/200
# 17/17 [==============================] - 0s 8ms/step - loss: 7.5618 - mean_absolute_percentage_error: 3.6409 - val_loss: 20.6299 - val_mean_absolute_percentage_error: 8.5784
# Epoch 43/200
# 17/17 [==============================] - 0s 9ms/step - loss: 10.1446 - mean_absolute_percentage_error: 4.8562 - val_loss: 48.6173 - val_mean_absolute_percentage_error: 17.2659
# Epoch 44/200
# 17/17 [==============================] - 0s 8ms/step - loss: 8.0225 - mean_absolute_percentage_error: 3.8290 - val_loss: 39.9513 - val_mean_absolute_percentage_error: 14.7460
# Epoch 45/200
# 17/17 [==============================] - 0s 8ms/step - loss: 7.9520 - mean_absolute_percentage_error: 3.7547 - val_loss: 27.7707 - val_mean_absolute_percentage_error: 10.6045
# Epoch 46/200
# 17/17 [==============================] - 0s 5ms/step - loss: 7.1069 - mean_absolute_percentage_error: 3.4136 - val_loss: 58.7142 - val_mean_absolute_percentage_error: 20.7190
# Epoch 47/200
# 17/17 [==============================] - 0s 5ms/step - loss: 13.7938 - mean_absolute_percentage_error: 6.5015 - val_loss: 32.3598 - val_mean_absolute_percentage_error: 12.5272
# Epoch 48/200
# 17/17 [==============================] - 0s 6ms/step - loss: 7.7633 - mean_absolute_percentage_error: 3.6923 - val_loss: 22.8529 - val_mean_absolute_percentage_error: 9.6654
# Epoch 49/200
# 17/17 [==============================] - 0s 6ms/step - loss: 6.6930 - mean_absolute_percentage_error: 3.2328 - val_loss: 37.8856 - val_mean_absolute_percentage_error: 14.2817
# Epoch 50/200
# 17/17 [==============================] - 0s 6ms/step - loss: 7.7750 - mean_absolute_percentage_error: 3.6848 - val_loss: 26.0350 - val_mean_absolute_percentage_error: 10.2008
# Epoch 51/200
# 17/17 [==============================] - 0s 6ms/step - loss: 6.5388 - mean_absolute_percentage_error: 3.1048 - val_loss: 24.3807 - val_mean_absolute_percentage_error: 9.6047
# Epoch 52/200
# 17/17 [==============================] - 0s 6ms/step - loss: 7.7444 - mean_absolute_percentage_error: 3.7225 - val_loss: 36.2135 - val_mean_absolute_percentage_error: 13.3947
# Epoch 53/200
# 17/17 [==============================] - 0s 6ms/step - loss: 13.9222 - mean_absolute_percentage_error: 6.5044 - val_loss: 22.6867 - val_mean_absolute_percentage_error: 8.8266
# Epoch 54/200
# 17/17 [==============================] - 0s 5ms/step - loss: 6.5348 - mean_absolute_percentage_error: 3.1603 - val_loss: 43.1955 - val_mean_absolute_percentage_error: 15.6938
# Epoch 55/200
# 17/17 [==============================] - 0s 6ms/step - loss: 7.3915 - mean_absolute_percentage_error: 3.5074 - val_loss: 31.0183 - val_mean_absolute_percentage_error: 11.5787
# Epoch 56/200
# 17/17 [==============================] - 0s 6ms/step - loss: 8.4834 - mean_absolute_percentage_error: 4.0871 - val_loss: 30.9324 - val_mean_absolute_percentage_error: 11.7026
# Epoch 57/200
# 17/17 [==============================] - 0s 5ms/step - loss: 11.6893 - mean_absolute_percentage_error: 5.5255 - val_loss: 24.9208 - val_mean_absolute_percentage_error: 9.6746
# Epoch 58/200
# 17/17 [==============================] - 0s 6ms/step - loss: 7.5901 - mean_absolute_percentage_error: 3.6307 - val_loss: 31.6392 - val_mean_absolute_percentage_error: 12.1603
# Epoch 59/200
# 17/17 [==============================] - 0s 6ms/step - loss: 6.1352 - mean_absolute_percentage_error: 2.9470 - val_loss: 30.0468 - val_mean_absolute_percentage_error: 11.6503
# Epoch 60/200
# 17/17 [==============================] - 0s 5ms/step - loss: 8.6339 - mean_absolute_percentage_error: 4.0986 - val_loss: 42.6874 - val_mean_absolute_percentage_error: 15.0543
# Epoch 61/200
# 17/17 [==============================] - 0s 6ms/step - loss: 8.8757 - mean_absolute_percentage_error: 4.2526 - val_loss: 44.2751 - val_mean_absolute_percentage_error: 16.2664
# Epoch 62/200
# 17/17 [==============================] - 0s 5ms/step - loss: 11.5657 - mean_absolute_percentage_error: 5.4201 - val_loss: 59.6369 - val_mean_absolute_percentage_error: 20.5813
# Epoch 63/200
# 17/17 [==============================] - 0s 5ms/step - loss: 7.8860 - mean_absolute_percentage_error: 3.7011 - val_loss: 42.2856 - val_mean_absolute_percentage_error: 15.3140
# Epoch 64/200
# 17/17 [==============================] - 0s 5ms/step - loss: 7.1181 - mean_absolute_percentage_error: 3.3766 - val_loss: 29.0218 - val_mean_absolute_percentage_error: 11.4022
# Epoch 65/200
# 17/17 [==============================] - 0s 5ms/step - loss: 7.1912 - mean_absolute_percentage_error: 3.3955 - val_loss: 35.3004 - val_mean_absolute_percentage_error: 13.1554
# Epoch 66/200
# 17/17 [==============================] - 0s 6ms/step - loss: 7.2890 - mean_absolute_percentage_error: 3.3922 - val_loss: 35.2649 - val_mean_absolute_percentage_error: 12.9016
# Epoch 67/200
# 17/17 [==============================] - 0s 6ms/step - loss: 7.4853 - mean_absolute_percentage_error: 3.5225 - val_loss: 32.0308 - val_mean_absolute_percentage_error: 12.3464
# Epoch 68/200
# 17/17 [==============================] - 0s 6ms/step - loss: 4.9065 - mean_absolute_percentage_error: 2.3528 - val_loss: 42.1512 - val_mean_absolute_percentage_error: 15.3620
# Epoch 69/200
# 17/17 [==============================] - 0s 6ms/step - loss: 6.1764 - mean_absolute_percentage_error: 2.9236 - val_loss: 30.9113 - val_mean_absolute_percentage_error: 11.9285
# Epoch 70/200
# 17/17 [==============================] - 0s 6ms/step - loss: 6.5861 - mean_absolute_percentage_error: 3.1164 - val_loss: 51.3215 - val_mean_absolute_percentage_error: 18.0116
# Epoch 71/200
# 17/17 [==============================] - 0s 6ms/step - loss: 6.9688 - mean_absolute_percentage_error: 3.2730 - val_loss: 24.9482 - val_mean_absolute_percentage_error: 10.2890
# Epoch 72/200
# 17/17 [==============================] - 0s 6ms/step - loss: 13.3824 - mean_absolute_percentage_error: 6.2746 - val_loss: 19.0676 - val_mean_absolute_percentage_error: 7.8735
# Epoch 73/200
# 17/17 [==============================] - 0s 6ms/step - loss: 10.0738 - mean_absolute_percentage_error: 4.7973 - val_loss: 29.5888 - val_mean_absolute_percentage_error: 11.6763
# Epoch 74/200
# 17/17 [==============================] - 0s 6ms/step - loss: 9.0694 - mean_absolute_percentage_error: 4.3392 - val_loss: 40.6580 - val_mean_absolute_percentage_error: 14.8243
# Epoch 75/200
# 17/17 [==============================] - 0s 7ms/step - loss: 9.1360 - mean_absolute_percentage_error: 4.3721 - val_loss: 38.6779 - val_mean_absolute_percentage_error: 13.9630
# Epoch 76/200
# 17/17 [==============================] - 0s 6ms/step - loss: 6.1638 - mean_absolute_percentage_error: 3.0215 - val_loss: 25.9716 - val_mean_absolute_percentage_error: 10.2934
# Epoch 77/200
# 17/17 [==============================] - 0s 5ms/step - loss: 11.8493 - mean_absolute_percentage_error: 5.6001 - val_loss: 15.8167 - val_mean_absolute_percentage_error: 6.4748
# Epoch 78/200
# 17/17 [==============================] - 0s 7ms/step - loss: 8.7895 - mean_absolute_percentage_error: 4.2343 - val_loss: 20.9214 - val_mean_absolute_percentage_error: 8.4896
# Epoch 79/200
# 17/17 [==============================] - 0s 6ms/step - loss: 6.7441 - mean_absolute_percentage_error: 3.2140 - val_loss: 21.2138 - val_mean_absolute_percentage_error: 8.8237
# Epoch 80/200
# 17/17 [==============================] - 0s 6ms/step - loss: 7.7580 - mean_absolute_percentage_error: 3.7882 - val_loss: 18.8041 - val_mean_absolute_percentage_error: 7.7675
# Epoch 81/200
# 17/17 [==============================] - 0s 6ms/step - loss: 12.2630 - mean_absolute_percentage_error: 5.7419 - val_loss: 37.7550 - val_mean_absolute_percentage_error: 13.7937
# Epoch 82/200
# 17/17 [==============================] - 0s 5ms/step - loss: 8.8914 - mean_absolute_percentage_error: 4.2357 - val_loss: 44.6726 - val_mean_absolute_percentage_error: 16.5649
# Epoch 83/200
# 17/17 [==============================] - 0s 6ms/step - loss: 6.1782 - mean_absolute_percentage_error: 2.9723 - val_loss: 17.1261 - val_mean_absolute_percentage_error: 7.2982
# Epoch 84/200
# 17/17 [==============================] - 0s 6ms/step - loss: 7.9284 - mean_absolute_percentage_error: 3.7582 - val_loss: 41.7550 - val_mean_absolute_percentage_error: 15.1002
# Epoch 85/200
# 17/17 [==============================] - 0s 6ms/step - loss: 6.8744 - mean_absolute_percentage_error: 3.2489 - val_loss: 38.0012 - val_mean_absolute_percentage_error: 14.3886
# Epoch 86/200
# 17/17 [==============================] - 0s 7ms/step - loss: 6.2743 - mean_absolute_percentage_error: 3.0013 - val_loss: 32.0267 - val_mean_absolute_percentage_error: 12.0563
# Epoch 87/200
# 17/17 [==============================] - 0s 6ms/step - loss: 6.9013 - mean_absolute_percentage_error: 3.3115 - val_loss: 36.7043 - val_mean_absolute_percentage_error: 13.4162
# Epoch 88/200
# 17/17 [==============================] - 0s 6ms/step - loss: 8.7895 - mean_absolute_percentage_error: 4.1581 - val_loss: 47.8418 - val_mean_absolute_percentage_error: 17.2983
# Epoch 89/200
# 17/17 [==============================] - 0s 6ms/step - loss: 10.6110 - mean_absolute_percentage_error: 5.1024 - val_loss: 55.0193 - val_mean_absolute_percentage_error: 19.4637
# Epoch 90/200
# 17/17 [==============================] - 0s 7ms/step - loss: 7.0295 - mean_absolute_percentage_error: 3.3466 - val_loss: 35.7209 - val_mean_absolute_percentage_error: 13.2428
# Epoch 91/200
# 17/17 [==============================] - 0s 7ms/step - loss: 6.6649 - mean_absolute_percentage_error: 3.1247 - val_loss: 43.8552 - val_mean_absolute_percentage_error: 15.2856
# Epoch 92/200
# 17/17 [==============================] - 0s 6ms/step - loss: 6.7484 - mean_absolute_percentage_error: 3.2311 - val_loss: 38.6103 - val_mean_absolute_percentage_error: 13.8956
# Epoch 93/200
# 17/17 [==============================] - 0s 6ms/step - loss: 6.4417 - mean_absolute_percentage_error: 3.0596 - val_loss: 29.3676 - val_mean_absolute_percentage_error: 11.0288
# Epoch 94/200
# 17/17 [==============================] - 0s 6ms/step - loss: 10.3288 - mean_absolute_percentage_error: 4.8377 - val_loss: 52.1148 - val_mean_absolute_percentage_error: 18.4430
# Epoch 95/200
# 17/17 [==============================] - 0s 6ms/step - loss: 9.5961 - mean_absolute_percentage_error: 4.5670 - val_loss: 44.9441 - val_mean_absolute_percentage_error: 15.9446
# Epoch 96/200
# 17/17 [==============================] - 0s 6ms/step - loss: 5.9566 - mean_absolute_percentage_error: 2.8625 - val_loss: 36.0490 - val_mean_absolute_percentage_error: 13.4100
# Epoch 97/200
# 17/17 [==============================] - 0s 6ms/step - loss: 5.8531 - mean_absolute_percentage_error: 2.7374 - val_loss: 31.3712 - val_mean_absolute_percentage_error: 11.9683
# Epoch 98/200
# 17/17 [==============================] - 0s 6ms/step - loss: 5.2978 - mean_absolute_percentage_error: 2.5328 - val_loss: 41.7528 - val_mean_absolute_percentage_error: 15.2683
# Epoch 99/200
# 17/17 [==============================] - 0s 6ms/step - loss: 5.9755 - mean_absolute_percentage_error: 2.8212 - val_loss: 28.0037 - val_mean_absolute_percentage_error: 10.5253
# Epoch 100/200
# 17/17 [==============================] - 0s 6ms/step - loss: 10.1692 - mean_absolute_percentage_error: 4.7818 - val_loss: 26.8974 - val_mean_absolute_percentage_error: 9.5435
# Epoch 101/200
# 17/17 [==============================] - 0s 6ms/step - loss: 7.0095 - mean_absolute_percentage_error: 3.3791 - val_loss: 32.7435 - val_mean_absolute_percentage_error: 12.1088
# Epoch 102/200
# 17/17 [==============================] - 0s 5ms/step - loss: 5.4320 - mean_absolute_percentage_error: 2.6607 - val_loss: 35.2442 - val_mean_absolute_percentage_error: 13.1040
# Epoch 103/200
# 17/17 [==============================] - 0s 5ms/step - loss: 5.4570 - mean_absolute_percentage_error: 2.6150 - val_loss: 31.3294 - val_mean_absolute_percentage_error: 11.5046
# Epoch 104/200
# 17/17 [==============================] - 0s 7ms/step - loss: 8.6094 - mean_absolute_percentage_error: 4.0958 - val_loss: 40.1910 - val_mean_absolute_percentage_error: 14.1660
# Epoch 105/200
# 17/17 [==============================] - 0s 6ms/step - loss: 5.7003 - mean_absolute_percentage_error: 2.7121 - val_loss: 43.6582 - val_mean_absolute_percentage_error: 15.6726
# Epoch 106/200
# 17/17 [==============================] - 0s 6ms/step - loss: 6.0409 - mean_absolute_percentage_error: 2.8756 - val_loss: 19.9298 - val_mean_absolute_percentage_error: 8.1781
# Epoch 107/200
# 17/17 [==============================] - 0s 7ms/step - loss: 6.8748 - mean_absolute_percentage_error: 3.2528 - val_loss: 26.8975 - val_mean_absolute_percentage_error: 10.6846
# Epoch 108/200
# 17/17 [==============================] - 0s 6ms/step - loss: 6.6554 - mean_absolute_percentage_error: 3.1404 - val_loss: 28.7955 - val_mean_absolute_percentage_error: 10.9393
# Epoch 109/200
# 17/17 [==============================] - 0s 7ms/step - loss: 6.6685 - mean_absolute_percentage_error: 3.1818 - val_loss: 36.2190 - val_mean_absolute_percentage_error: 12.9240
# Epoch 110/200
# 17/17 [==============================] - 0s 7ms/step - loss: 5.7025 - mean_absolute_percentage_error: 2.7359 - val_loss: 30.6678 - val_mean_absolute_percentage_error: 11.7716
# Epoch 111/200
# 17/17 [==============================] - 0s 7ms/step - loss: 5.7111 - mean_absolute_percentage_error: 2.6751 - val_loss: 36.4584 - val_mean_absolute_percentage_error: 13.2868
# Epoch 112/200
# 17/17 [==============================] - 0s 7ms/step - loss: 6.7963 - mean_absolute_percentage_error: 3.1899 - val_loss: 50.5761 - val_mean_absolute_percentage_error: 17.8794
# Epoch 113/200
# 17/17 [==============================] - 0s 7ms/step - loss: 6.8418 - mean_absolute_percentage_error: 3.2379 - val_loss: 39.8903 - val_mean_absolute_percentage_error: 14.6229
# Epoch 114/200
# 17/17 [==============================] - 0s 6ms/step - loss: 10.1811 - mean_absolute_percentage_error: 4.8099 - val_loss: 28.0330 - val_mean_absolute_percentage_error: 10.3151
# Epoch 115/200
# 17/17 [==============================] - 0s 6ms/step - loss: 8.2353 - mean_absolute_percentage_error: 3.9201 - val_loss: 36.2752 - val_mean_absolute_percentage_error: 13.3766
# Epoch 116/200
# 17/17 [==============================] - 0s 5ms/step - loss: 6.1975 - mean_absolute_percentage_error: 2.9407 - val_loss: 43.0572 - val_mean_absolute_percentage_error: 15.3901
# Epoch 117/200
# 17/17 [==============================] - 0s 6ms/step - loss: 7.1985 - mean_absolute_percentage_error: 3.4197 - val_loss: 24.0440 - val_mean_absolute_percentage_error: 9.4666
# Epoch 118/200
# 17/17 [==============================] - 0s 7ms/step - loss: 5.7991 - mean_absolute_percentage_error: 2.8011 - val_loss: 24.2623 - val_mean_absolute_percentage_error: 9.6821
# Epoch 119/200
# 17/17 [==============================] - 0s 6ms/step - loss: 7.5383 - mean_absolute_percentage_error: 3.6037 - val_loss: 42.6510 - val_mean_absolute_percentage_error: 15.0438
# Epoch 120/200
# 17/17 [==============================] - 0s 7ms/step - loss: 5.8346 - mean_absolute_percentage_error: 2.7824 - val_loss: 34.2000 - val_mean_absolute_percentage_error: 12.8193
# Epoch 121/200
# 17/17 [==============================] - 0s 6ms/step - loss: 5.5155 - mean_absolute_percentage_error: 2.6087 - val_loss: 40.5872 - val_mean_absolute_percentage_error: 14.4553
# Epoch 122/200
# 17/17 [==============================] - 0s 6ms/step - loss: 5.4578 - mean_absolute_percentage_error: 2.6059 - val_loss: 29.7235 - val_mean_absolute_percentage_error: 11.1424
# Epoch 123/200
# 17/17 [==============================] - 0s 6ms/step - loss: 7.3749 - mean_absolute_percentage_error: 3.4510 - val_loss: 29.9453 - val_mean_absolute_percentage_error: 11.0686
# Epoch 124/200
# 17/17 [==============================] - 0s 7ms/step - loss: 5.2102 - mean_absolute_percentage_error: 2.4885 - val_loss: 34.6816 - val_mean_absolute_percentage_error: 13.5187
# Epoch 125/200
# 17/17 [==============================] - 0s 6ms/step - loss: 7.6974 - mean_absolute_percentage_error: 3.6821 - val_loss: 24.9981 - val_mean_absolute_percentage_error: 9.7177
# Epoch 126/200
# 17/17 [==============================] - 0s 7ms/step - loss: 8.1433 - mean_absolute_percentage_error: 3.8470 - val_loss: 49.2674 - val_mean_absolute_percentage_error: 17.2709
# Epoch 127/200
# 17/17 [==============================] - 0s 6ms/step - loss: 7.7022 - mean_absolute_percentage_error: 3.5770 - val_loss: 16.0393 - val_mean_absolute_percentage_error: 6.4606
# Epoch 128/200
# 17/17 [==============================] - 0s 7ms/step - loss: 11.0990 - mean_absolute_percentage_error: 5.3128 - val_loss: 27.5445 - val_mean_absolute_percentage_error: 10.7114
# Epoch 129/200
# 17/17 [==============================] - 0s 6ms/step - loss: 6.6970 - mean_absolute_percentage_error: 3.1210 - val_loss: 28.3749 - val_mean_absolute_percentage_error: 10.4170
# Epoch 130/200
# 17/17 [==============================] - 0s 6ms/step - loss: 6.5361 - mean_absolute_percentage_error: 3.1756 - val_loss: 22.3216 - val_mean_absolute_percentage_error: 9.0346
# Epoch 131/200
# 17/17 [==============================] - 0s 7ms/step - loss: 6.1490 - mean_absolute_percentage_error: 2.9692 - val_loss: 36.9245 - val_mean_absolute_percentage_error: 13.3326
# Epoch 132/200
# 17/17 [==============================] - 0s 7ms/step - loss: 5.8454 - mean_absolute_percentage_error: 2.7931 - val_loss: 31.5272 - val_mean_absolute_percentage_error: 11.9658
# Epoch 133/200
# 17/17 [==============================] - 0s 6ms/step - loss: 5.1259 - mean_absolute_percentage_error: 2.4145 - val_loss: 34.2611 - val_mean_absolute_percentage_error: 12.9457
# Epoch 134/200
# 17/17 [==============================] - 0s 6ms/step - loss: 5.4706 - mean_absolute_percentage_error: 2.5822 - val_loss: 34.9830 - val_mean_absolute_percentage_error: 12.9324
# Epoch 135/200
# 17/17 [==============================] - 0s 6ms/step - loss: 5.3210 - mean_absolute_percentage_error: 2.5149 - val_loss: 23.9117 - val_mean_absolute_percentage_error: 9.0258
# Epoch 136/200
# 17/17 [==============================] - 0s 8ms/step - loss: 8.3396 - mean_absolute_percentage_error: 4.0154 - val_loss: 30.3449 - val_mean_absolute_percentage_error: 11.4236
# Epoch 137/200
# 17/17 [==============================] - 0s 9ms/step - loss: 5.3155 - mean_absolute_percentage_error: 2.5671 - val_loss: 29.4015 - val_mean_absolute_percentage_error: 10.9765
# Epoch 138/200
# 17/17 [==============================] - 0s 9ms/step - loss: 5.9120 - mean_absolute_percentage_error: 2.8493 - val_loss: 29.0006 - val_mean_absolute_percentage_error: 11.0970
# Epoch 139/200
# 17/17 [==============================] - 0s 8ms/step - loss: 9.4390 - mean_absolute_percentage_error: 4.4771 - val_loss: 55.0621 - val_mean_absolute_percentage_error: 19.3310
# Epoch 140/200
# 17/17 [==============================] - 0s 8ms/step - loss: 10.3302 - mean_absolute_percentage_error: 4.9102 - val_loss: 24.1147 - val_mean_absolute_percentage_error: 9.3183
# Epoch 141/200
# 17/17 [==============================] - 0s 10ms/step - loss: 5.8597 - mean_absolute_percentage_error: 2.7611 - val_loss: 22.6636 - val_mean_absolute_percentage_error: 8.9851
# Epoch 142/200
# 17/17 [==============================] - 0s 8ms/step - loss: 6.0312 - mean_absolute_percentage_error: 2.8943 - val_loss: 45.9190 - val_mean_absolute_percentage_error: 16.5747
# Epoch 143/200
# 17/17 [==============================] - 0s 9ms/step - loss: 10.1003 - mean_absolute_percentage_error: 4.8736 - val_loss: 56.1100 - val_mean_absolute_percentage_error: 19.4384
# Epoch 144/200
# 17/17 [==============================] - 0s 9ms/step - loss: 7.4092 - mean_absolute_percentage_error: 3.5038 - val_loss: 35.4538 - val_mean_absolute_percentage_error: 13.0533
# Epoch 145/200
# 17/17 [==============================] - 0s 8ms/step - loss: 5.8401 - mean_absolute_percentage_error: 2.7879 - val_loss: 47.1098 - val_mean_absolute_percentage_error: 16.8451
# Epoch 146/200
# 17/17 [==============================] - 0s 8ms/step - loss: 5.3981 - mean_absolute_percentage_error: 2.5508 - val_loss: 27.2128 - val_mean_absolute_percentage_error: 10.5823
# Epoch 147/200
# 17/17 [==============================] - 0s 9ms/step - loss: 6.6049 - mean_absolute_percentage_error: 3.0886 - val_loss: 41.3840 - val_mean_absolute_percentage_error: 14.8091
# Epoch 148/200
# 17/17 [==============================] - 0s 8ms/step - loss: 9.2089 - mean_absolute_percentage_error: 4.3937 - val_loss: 17.5659 - val_mean_absolute_percentage_error: 7.4975
# Epoch 149/200
# 17/17 [==============================] - 0s 9ms/step - loss: 7.5778 - mean_absolute_percentage_error: 3.5998 - val_loss: 27.1452 - val_mean_absolute_percentage_error: 10.2595
# Epoch 150/200
# 17/17 [==============================] - 0s 7ms/step - loss: 8.7875 - mean_absolute_percentage_error: 4.1494 - val_loss: 29.3010 - val_mean_absolute_percentage_error: 11.0386
# Epoch 151/200
# 17/17 [==============================] - 0s 8ms/step - loss: 5.9588 - mean_absolute_percentage_error: 2.8178 - val_loss: 26.2209 - val_mean_absolute_percentage_error: 10.3031
# Epoch 152/200
# 17/17 [==============================] - 0s 8ms/step - loss: 5.5898 - mean_absolute_percentage_error: 2.6624 - val_loss: 37.1502 - val_mean_absolute_percentage_error: 13.4529
# Epoch 153/200
# 17/17 [==============================] - 0s 9ms/step - loss: 5.3425 - mean_absolute_percentage_error: 2.5324 - val_loss: 30.6089 - val_mean_absolute_percentage_error: 11.7365
# Epoch 154/200
# 17/17 [==============================] - 0s 8ms/step - loss: 5.4825 - mean_absolute_percentage_error: 2.5903 - val_loss: 36.3075 - val_mean_absolute_percentage_error: 13.3234
# Epoch 155/200
# 17/17 [==============================] - 0s 7ms/step - loss: 5.3126 - mean_absolute_percentage_error: 2.5547 - val_loss: 18.3816 - val_mean_absolute_percentage_error: 7.7664
# Epoch 156/200
# 17/17 [==============================] - 0s 8ms/step - loss: 6.9703 - mean_absolute_percentage_error: 3.2941 - val_loss: 33.3128 - val_mean_absolute_percentage_error: 12.2718
# Epoch 157/200
# 17/17 [==============================] - 0s 7ms/step - loss: 5.7940 - mean_absolute_percentage_error: 2.7848 - val_loss: 33.2895 - val_mean_absolute_percentage_error: 12.0260
# Epoch 158/200
# 17/17 [==============================] - 0s 9ms/step - loss: 5.9372 - mean_absolute_percentage_error: 2.8217 - val_loss: 22.6308 - val_mean_absolute_percentage_error: 8.6031
# Epoch 159/200
# 17/17 [==============================] - 0s 8ms/step - loss: 6.3819 - mean_absolute_percentage_error: 2.9884 - val_loss: 17.0361 - val_mean_absolute_percentage_error: 7.2628
# Epoch 160/200
# 17/17 [==============================] - 0s 8ms/step - loss: 9.2238 - mean_absolute_percentage_error: 4.4319 - val_loss: 17.0218 - val_mean_absolute_percentage_error: 7.1158
# Epoch 161/200
# 17/17 [==============================] - 0s 8ms/step - loss: 6.3904 - mean_absolute_percentage_error: 3.0865 - val_loss: 29.4074 - val_mean_absolute_percentage_error: 10.9530
# Epoch 162/200
# 17/17 [==============================] - 0s 9ms/step - loss: 5.5452 - mean_absolute_percentage_error: 2.6162 - val_loss: 23.2441 - val_mean_absolute_percentage_error: 9.0758
# Epoch 163/200
# 17/17 [==============================] - 0s 9ms/step - loss: 6.1753 - mean_absolute_percentage_error: 2.8919 - val_loss: 33.6629 - val_mean_absolute_percentage_error: 12.4588
# Epoch 164/200
# 17/17 [==============================] - 0s 8ms/step - loss: 5.5203 - mean_absolute_percentage_error: 2.6564 - val_loss: 24.5549 - val_mean_absolute_percentage_error: 9.7385
# Epoch 165/200
# 17/17 [==============================] - 0s 6ms/step - loss: 5.0352 - mean_absolute_percentage_error: 2.3570 - val_loss: 27.6192 - val_mean_absolute_percentage_error: 10.4708
# Epoch 166/200
# 17/17 [==============================] - 0s 7ms/step - loss: 5.2288 - mean_absolute_percentage_error: 2.5097 - val_loss: 36.9334 - val_mean_absolute_percentage_error: 13.5849
# Epoch 167/200
# 17/17 [==============================] - 0s 6ms/step - loss: 5.6443 - mean_absolute_percentage_error: 2.6788 - val_loss: 41.3424 - val_mean_absolute_percentage_error: 14.9332
# Epoch 168/200
# 17/17 [==============================] - 0s 6ms/step - loss: 8.0068 - mean_absolute_percentage_error: 3.8017 - val_loss: 43.8731 - val_mean_absolute_percentage_error: 14.8615
# Epoch 169/200
# 17/17 [==============================] - 0s 6ms/step - loss: 6.8416 - mean_absolute_percentage_error: 3.3286 - val_loss: 49.1011 - val_mean_absolute_percentage_error: 17.0610
# Epoch 170/200
# 17/17 [==============================] - 0s 7ms/step - loss: 6.2892 - mean_absolute_percentage_error: 3.0209 - val_loss: 23.4812 - val_mean_absolute_percentage_error: 9.0088
# Epoch 171/200
# 17/17 [==============================] - 0s 6ms/step - loss: 6.1931 - mean_absolute_percentage_error: 2.9452 - val_loss: 29.2324 - val_mean_absolute_percentage_error: 10.7818
# Epoch 172/200
# 17/17 [==============================] - 0s 7ms/step - loss: 5.7248 - mean_absolute_percentage_error: 2.7472 - val_loss: 29.7775 - val_mean_absolute_percentage_error: 11.0877
# Epoch 173/200
# 17/17 [==============================] - 0s 7ms/step - loss: 7.9982 - mean_absolute_percentage_error: 3.8410 - val_loss: 23.5634 - val_mean_absolute_percentage_error: 9.2671
# Epoch 174/200
# 17/17 [==============================] - 0s 7ms/step - loss: 5.9687 - mean_absolute_percentage_error: 2.8837 - val_loss: 28.3355 - val_mean_absolute_percentage_error: 10.3165
# Epoch 175/200
# 17/17 [==============================] - 0s 6ms/step - loss: 5.6259 - mean_absolute_percentage_error: 2.7038 - val_loss: 42.9462 - val_mean_absolute_percentage_error: 15.0702
# Epoch 176/200
# 17/17 [==============================] - 0s 6ms/step - loss: 6.4741 - mean_absolute_percentage_error: 3.0818 - val_loss: 22.9211 - val_mean_absolute_percentage_error: 9.0512
# Epoch 177/200
# 17/17 [==============================] - 0s 7ms/step - loss: 5.5128 - mean_absolute_percentage_error: 2.6172 - val_loss: 23.0677 - val_mean_absolute_percentage_error: 9.1584
# Epoch 178/200
# 17/17 [==============================] - 0s 7ms/step - loss: 6.0884 - mean_absolute_percentage_error: 2.8854 - val_loss: 45.5657 - val_mean_absolute_percentage_error: 16.2501
# Epoch 179/200
# 17/17 [==============================] - 0s 7ms/step - loss: 6.3392 - mean_absolute_percentage_error: 2.9732 - val_loss: 16.7313 - val_mean_absolute_percentage_error: 6.4875
# Epoch 180/200
# 17/17 [==============================] - 0s 7ms/step - loss: 7.5324 - mean_absolute_percentage_error: 3.6592 - val_loss: 32.2476 - val_mean_absolute_percentage_error: 11.5876
# Epoch 181/200
# 17/17 [==============================] - 0s 6ms/step - loss: 5.7198 - mean_absolute_percentage_error: 2.7475 - val_loss: 45.2249 - val_mean_absolute_percentage_error: 16.3426
# Epoch 182/200
# 17/17 [==============================] - 0s 6ms/step - loss: 7.7734 - mean_absolute_percentage_error: 3.7695 - val_loss: 33.0130 - val_mean_absolute_percentage_error: 12.4243
# Epoch 183/200
# 17/17 [==============================] - 0s 6ms/step - loss: 7.1362 - mean_absolute_percentage_error: 3.4495 - val_loss: 18.9910 - val_mean_absolute_percentage_error: 7.8158
# Epoch 184/200
# 17/17 [==============================] - 0s 6ms/step - loss: 8.1004 - mean_absolute_percentage_error: 3.8712 - val_loss: 25.8314 - val_mean_absolute_percentage_error: 10.1030
# Epoch 185/200
# 17/17 [==============================] - 0s 6ms/step - loss: 8.8604 - mean_absolute_percentage_error: 4.2623 - val_loss: 46.0682 - val_mean_absolute_percentage_error: 16.3782
# Epoch 186/200
# 17/17 [==============================] - 0s 7ms/step - loss: 8.1564 - mean_absolute_percentage_error: 3.8911 - val_loss: 32.8309 - val_mean_absolute_percentage_error: 12.3763
# Epoch 187/200
# 17/17 [==============================] - 0s 6ms/step - loss: 7.9996 - mean_absolute_percentage_error: 3.7987 - val_loss: 38.5442 - val_mean_absolute_percentage_error: 13.8867
# Epoch 188/200
# 17/17 [==============================] - 0s 6ms/step - loss: 11.0687 - mean_absolute_percentage_error: 5.2900 - val_loss: 50.4874 - val_mean_absolute_percentage_error: 17.4973
# Epoch 189/200
# 17/17 [==============================] - 0s 7ms/step - loss: 6.9130 - mean_absolute_percentage_error: 3.2675 - val_loss: 38.5604 - val_mean_absolute_percentage_error: 13.7078
# Epoch 190/200
# 17/17 [==============================] - 0s 7ms/step - loss: 5.1210 - mean_absolute_percentage_error: 2.4283 - val_loss: 16.3943 - val_mean_absolute_percentage_error: 6.7790
# Epoch 191/200
# 17/17 [==============================] - 0s 7ms/step - loss: 6.5235 - mean_absolute_percentage_error: 3.0505 - val_loss: 38.9933 - val_mean_absolute_percentage_error: 13.8858
# Epoch 192/200
# 17/17 [==============================] - 0s 7ms/step - loss: 4.9555 - mean_absolute_percentage_error: 2.3455 - val_loss: 34.0832 - val_mean_absolute_percentage_error: 12.5749
# Epoch 193/200
# 17/17 [==============================] - 0s 6ms/step - loss: 5.0190 - mean_absolute_percentage_error: 2.3792 - val_loss: 22.4310 - val_mean_absolute_percentage_error: 8.9676
# Epoch 194/200
# 17/17 [==============================] - 0s 6ms/step - loss: 4.6542 - mean_absolute_percentage_error: 2.2467 - val_loss: 30.2574 - val_mean_absolute_percentage_error: 11.3399
# Epoch 195/200
# 17/17 [==============================] - 0s 7ms/step - loss: 4.8452 - mean_absolute_percentage_error: 2.3341 - val_loss: 33.7673 - val_mean_absolute_percentage_error: 12.2433
# Epoch 196/200
# 17/17 [==============================] - 0s 7ms/step - loss: 4.6457 - mean_absolute_percentage_error: 2.2169 - val_loss: 22.5536 - val_mean_absolute_percentage_error: 8.6847
# Epoch 197/200
# 17/17 [==============================] - 0s 6ms/step - loss: 5.5618 - mean_absolute_percentage_error: 2.6492 - val_loss: 27.3616 - val_mean_absolute_percentage_error: 10.4310
# Epoch 198/200
# 17/17 [==============================] - 0s 7ms/step - loss: 7.8496 - mean_absolute_percentage_error: 3.7761 - val_loss: 32.9551 - val_mean_absolute_percentage_error: 11.9941
# Epoch 199/200
# 17/17 [==============================] - 0s 7ms/step - loss: 5.0921 - mean_absolute_percentage_error: 2.4586 - val_loss: 39.6836 - val_mean_absolute_percentage_error: 14.3366
# Epoch 200/200
# 17/17 [==============================] - 0s 6ms/step - loss: 5.8295 - mean_absolute_percentage_error: 2.7684 - val_loss: 33.3611 - val_mean_absolute_percentage_error: 11.7947

# %%
# Check the dictionary keys
modeling_result=history.history
modeling_result.keys()
# Out:
# dict_keys(['loss', 'mean_absolute_percentage_error', 'val_loss', 'val_mean_absolute_percentage_error'])

# %%
# 7.2 Plot the history of training and validation
training_loss_values=modeling_result['loss']
val_loss_values=modeling_result['val_loss']
epochs=range(1,len(training_loss_values)+1)

plt.figure(figsize=(12,10),dpi=300)
plt.xlabel('Epochs',fontsize=20)
plt.ylabel('Loss (Root Mean Squared Error,RMSE)',fontsize=20)
plt.title('Meta DNN training & validation of Loss result ',fontsize=20)

plt.plot(epochs, training_loss_values,marker='.',label='training Loss')
plt.plot(epochs, val_loss_values,marker='.',label='validation Loss')
plt.legend(loc=1,fontsize=24)
plt.show()

# %%
# 7.2 Plot the history of training and validation
training_acc_values=modeling_result['mean_absolute_percentage_error']
val_acc_values=modeling_result['val_mean_absolute_percentage_error']
epochs=range(1,len(training_acc_values)+1)

plt.figure(figsize=(12,10),dpi=300)
plt.xlabel('Epochs',fontsize=20)
plt.ylabel('Mean Absolute Percentage Error, MAPE',fontsize=20)
plt.title('Meta ANN training & validation of MAPE result ',fontsize=20)

plt.plot(epochs, training_acc_values,marker='.',label='training MAPE')
plt.plot(epochs, val_acc_values,marker='.',label='validation MAPE')
plt.legend(loc=1,fontsize=24)
plt.show()

# %% [markdown]
# # Fit the final model with all of the training data

# %%
# X all train data
x_forecast_train=Forecast_train_data.drop(['Date','Close'],axis=1).copy()
# Y all train data
y_forecast_train=Forecast_train_data['Close'].copy()

# %%
# Create the model
clear.clear_session()
Fmodel=Sequential()

# 6.2 Add input layer & first hidden layer
Fmodel.add(Dense(units=6, input_dim=3, activation='relu'))

# 6.3 Add 5 dense layers
dense_generator(Fmodel,5,6)

# Add dropout layer
Fmodel.add(Dropout(rate=0.2))

# Add 2 more dense layers
dense_generator(Fmodel,2,192)

# Add output layer
Fmodel.add(Dense(units=1, activation='linear'))

# Compile the defined Net
#opt=SGD(learning_rate=0.001,momentum=0.5)
opt=Adam(learning_rate=0.01,beta_1=0.8)
Fmodel.compile(loss='my_RMSE', optimizer=opt, metrics=['mean_absolute_percentage_error'])

# Finally check the model 
Fmodel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 6)                 24
#
#  dense_1 (Dense)             (None, 12)                84
#
#  dense_2 (Dense)             (None, 24)                312
#
#  dense_3 (Dense)             (None, 48)                1200
#
#  dense_4 (Dense)             (None, 96)                4704
#
#  dense_5 (Dense)             (None, 192)               18624
#
#  dropout (Dropout)           (None, 192)               0
#
#  dense_6 (Dense)             (None, 384)               74112
#
#  dense_7 (Dense)             (None, 768)               295680
#
#  dense_8 (Dense)             (None, 1)                 769
#
# =================================================================
# Total params: 395,509
# Trainable params: 395,509
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Store in the history for more useful information
history=Fmodel.fit(x_forecast_train, y_forecast_train, epochs=200, batch_size=64,verbose=1)
# Out:
# Epoch 1/200
# 20/20 [==============================] - 1s 5ms/step - loss: 120.3091 - mean_absolute_percentage_error: 54.7660
# Epoch 2/200
# 20/20 [==============================] - 0s 5ms/step - loss: 36.5537 - mean_absolute_percentage_error: 16.7046
# Epoch 3/200
# 20/20 [==============================] - 0s 5ms/step - loss: 30.4585 - mean_absolute_percentage_error: 13.7035
# Epoch 4/200
# 20/20 [==============================] - 0s 5ms/step - loss: 28.2897 - mean_absolute_percentage_error: 12.8313
# Epoch 5/200
# 20/20 [==============================] - 0s 5ms/step - loss: 30.9648 - mean_absolute_percentage_error: 14.1139
# Epoch 6/200
# 20/20 [==============================] - 0s 5ms/step - loss: 37.4509 - mean_absolute_percentage_error: 16.9349
# Epoch 7/200
# 20/20 [==============================] - 0s 4ms/step - loss: 18.6574 - mean_absolute_percentage_error: 8.5659
# Epoch 8/200
# 20/20 [==============================] - 0s 5ms/step - loss: 23.8212 - mean_absolute_percentage_error: 10.8498
# Epoch 9/200
# 20/20 [==============================] - 0s 5ms/step - loss: 25.4503 - mean_absolute_percentage_error: 11.3953
# Epoch 10/200
# 20/20 [==============================] - 0s 5ms/step - loss: 21.9987 - mean_absolute_percentage_error: 9.9734
# Epoch 11/200
# 20/20 [==============================] - 0s 5ms/step - loss: 18.7783 - mean_absolute_percentage_error: 8.4981
# Epoch 12/200
# 20/20 [==============================] - 0s 5ms/step - loss: 16.2801 - mean_absolute_percentage_error: 7.3486
# Epoch 13/200
# 20/20 [==============================] - 0s 5ms/step - loss: 45.9202 - mean_absolute_percentage_error: 20.7392
# Epoch 14/200
# 20/20 [==============================] - 0s 5ms/step - loss: 17.9579 - mean_absolute_percentage_error: 8.1100
# Epoch 15/200
# 20/20 [==============================] - 0s 5ms/step - loss: 19.0843 - mean_absolute_percentage_error: 8.6308
# Epoch 16/200
# 20/20 [==============================] - 0s 5ms/step - loss: 20.0291 - mean_absolute_percentage_error: 9.0676
# Epoch 17/200
# 20/20 [==============================] - 0s 5ms/step - loss: 14.9937 - mean_absolute_percentage_error: 6.7857
# Epoch 18/200
# 20/20 [==============================] - 0s 5ms/step - loss: 16.7021 - mean_absolute_percentage_error: 7.5670
# Epoch 19/200
# 20/20 [==============================] - 0s 5ms/step - loss: 38.3583 - mean_absolute_percentage_error: 17.2312
# Epoch 20/200
# 20/20 [==============================] - 0s 5ms/step - loss: 34.5261 - mean_absolute_percentage_error: 15.5551
# Epoch 21/200
# 20/20 [==============================] - 0s 4ms/step - loss: 17.5738 - mean_absolute_percentage_error: 7.8555
# Epoch 22/200
# 20/20 [==============================] - 0s 3ms/step - loss: 16.3222 - mean_absolute_percentage_error: 7.4181
# Epoch 23/200
# 20/20 [==============================] - 0s 4ms/step - loss: 14.9822 - mean_absolute_percentage_error: 6.7470
# Epoch 24/200
# 20/20 [==============================] - 0s 4ms/step - loss: 17.9710 - mean_absolute_percentage_error: 8.0817
# Epoch 25/200
# 20/20 [==============================] - 0s 4ms/step - loss: 19.6610 - mean_absolute_percentage_error: 8.9175
# Epoch 26/200
# 20/20 [==============================] - 0s 4ms/step - loss: 27.7248 - mean_absolute_percentage_error: 12.5013
# Epoch 27/200
# 20/20 [==============================] - 0s 4ms/step - loss: 28.2709 - mean_absolute_percentage_error: 12.7555
# Epoch 28/200
# 20/20 [==============================] - 0s 4ms/step - loss: 16.5586 - mean_absolute_percentage_error: 7.4479
# Epoch 29/200
# 20/20 [==============================] - 0s 3ms/step - loss: 14.7766 - mean_absolute_percentage_error: 6.6938
# Epoch 30/200
# 20/20 [==============================] - 0s 4ms/step - loss: 14.9166 - mean_absolute_percentage_error: 6.7514
# Epoch 31/200
# 20/20 [==============================] - 0s 4ms/step - loss: 33.1525 - mean_absolute_percentage_error: 14.9161
# Epoch 32/200
# 20/20 [==============================] - 0s 4ms/step - loss: 17.2734 - mean_absolute_percentage_error: 7.7337
# Epoch 33/200
# 20/20 [==============================] - 0s 4ms/step - loss: 20.4237 - mean_absolute_percentage_error: 9.1946
# Epoch 34/200
# 20/20 [==============================] - 0s 3ms/step - loss: 22.9793 - mean_absolute_percentage_error: 10.3619
# Epoch 35/200
# 20/20 [==============================] - 0s 4ms/step - loss: 19.7823 - mean_absolute_percentage_error: 8.9023
# Epoch 36/200
# 20/20 [==============================] - 0s 4ms/step - loss: 13.7898 - mean_absolute_percentage_error: 6.2086
# Epoch 37/200
# 20/20 [==============================] - 0s 4ms/step - loss: 12.6072 - mean_absolute_percentage_error: 5.6646
# Epoch 38/200
# 20/20 [==============================] - 0s 4ms/step - loss: 12.5703 - mean_absolute_percentage_error: 5.6366
# Epoch 39/200
# 20/20 [==============================] - 0s 4ms/step - loss: 17.4036 - mean_absolute_percentage_error: 7.6885
# Epoch 40/200
# 20/20 [==============================] - 0s 4ms/step - loss: 14.8313 - mean_absolute_percentage_error: 6.6744
# Epoch 41/200
# 20/20 [==============================] - 0s 3ms/step - loss: 11.5516 - mean_absolute_percentage_error: 5.0848
# Epoch 42/200
# 20/20 [==============================] - 0s 4ms/step - loss: 13.2486 - mean_absolute_percentage_error: 5.9538
# Epoch 43/200
# 20/20 [==============================] - 0s 4ms/step - loss: 22.2903 - mean_absolute_percentage_error: 9.9383
# Epoch 44/200
# 20/20 [==============================] - 0s 4ms/step - loss: 18.3145 - mean_absolute_percentage_error: 8.1221
# Epoch 45/200
# 20/20 [==============================] - 0s 4ms/step - loss: 11.3726 - mean_absolute_percentage_error: 5.0453
# Epoch 46/200
# 20/20 [==============================] - 0s 4ms/step - loss: 10.7577 - mean_absolute_percentage_error: 4.7522
# Epoch 47/200
# 20/20 [==============================] - 0s 3ms/step - loss: 12.3890 - mean_absolute_percentage_error: 5.4771
# Epoch 48/200
# 20/20 [==============================] - 0s 4ms/step - loss: 18.4248 - mean_absolute_percentage_error: 8.1553
# Epoch 49/200
# 20/20 [==============================] - 0s 4ms/step - loss: 28.4411 - mean_absolute_percentage_error: 12.5933
# Epoch 50/200
# 20/20 [==============================] - 0s 4ms/step - loss: 17.6951 - mean_absolute_percentage_error: 7.9303
# Epoch 51/200
# 20/20 [==============================] - 0s 4ms/step - loss: 11.1476 - mean_absolute_percentage_error: 4.9673
# Epoch 52/200
# 20/20 [==============================] - 0s 4ms/step - loss: 11.1396 - mean_absolute_percentage_error: 4.9311
# Epoch 53/200
# 20/20 [==============================] - 0s 3ms/step - loss: 11.5273 - mean_absolute_percentage_error: 5.0794
# Epoch 54/200
# 20/20 [==============================] - 0s 4ms/step - loss: 19.0480 - mean_absolute_percentage_error: 8.5200
# Epoch 55/200
# 20/20 [==============================] - 0s 4ms/step - loss: 13.4785 - mean_absolute_percentage_error: 6.0142
# Epoch 56/200
# 20/20 [==============================] - 0s 4ms/step - loss: 11.2192 - mean_absolute_percentage_error: 4.8887
# Epoch 57/200
# 20/20 [==============================] - 0s 4ms/step - loss: 21.0921 - mean_absolute_percentage_error: 9.3152
# Epoch 58/200
# 20/20 [==============================] - 0s 3ms/step - loss: 11.4133 - mean_absolute_percentage_error: 5.0697
# Epoch 59/200
# 20/20 [==============================] - 0s 4ms/step - loss: 10.2610 - mean_absolute_percentage_error: 4.5583
# Epoch 60/200
# 20/20 [==============================] - 0s 4ms/step - loss: 19.7369 - mean_absolute_percentage_error: 8.6674
# Epoch 61/200
# 20/20 [==============================] - 0s 4ms/step - loss: 14.2017 - mean_absolute_percentage_error: 6.3114
# Epoch 62/200
# 20/20 [==============================] - 0s 4ms/step - loss: 12.8005 - mean_absolute_percentage_error: 5.6729
# Epoch 63/200
# 20/20 [==============================] - 0s 4ms/step - loss: 10.0106 - mean_absolute_percentage_error: 4.4014
# Epoch 64/200
# 20/20 [==============================] - 0s 4ms/step - loss: 12.3932 - mean_absolute_percentage_error: 5.4595
# Epoch 65/200
# 20/20 [==============================] - 0s 4ms/step - loss: 11.0240 - mean_absolute_percentage_error: 4.8270
# Epoch 66/200
# 20/20 [==============================] - 0s 4ms/step - loss: 12.6705 - mean_absolute_percentage_error: 5.6752
# Epoch 67/200
# 20/20 [==============================] - 0s 4ms/step - loss: 9.1602 - mean_absolute_percentage_error: 3.9750
# Epoch 68/200
# 20/20 [==============================] - 0s 4ms/step - loss: 9.2853 - mean_absolute_percentage_error: 4.1237
# Epoch 69/200
# 20/20 [==============================] - 0s 4ms/step - loss: 14.5113 - mean_absolute_percentage_error: 6.4889
# Epoch 70/200
# 20/20 [==============================] - 0s 4ms/step - loss: 12.8075 - mean_absolute_percentage_error: 5.7295
# Epoch 71/200
# 20/20 [==============================] - 0s 4ms/step - loss: 10.9799 - mean_absolute_percentage_error: 4.8052
# Epoch 72/200
# 20/20 [==============================] - 0s 4ms/step - loss: 18.1264 - mean_absolute_percentage_error: 8.0311
# Epoch 73/200
# 20/20 [==============================] - 0s 4ms/step - loss: 9.2440 - mean_absolute_percentage_error: 4.0637
# Epoch 74/200
# 20/20 [==============================] - 0s 4ms/step - loss: 10.4143 - mean_absolute_percentage_error: 4.5890
# Epoch 75/200
# 20/20 [==============================] - 0s 3ms/step - loss: 17.6970 - mean_absolute_percentage_error: 7.8821
# Epoch 76/200
# 20/20 [==============================] - 0s 4ms/step - loss: 11.6146 - mean_absolute_percentage_error: 5.1243
# Epoch 77/200
# 20/20 [==============================] - 0s 4ms/step - loss: 12.2051 - mean_absolute_percentage_error: 5.3603
# Epoch 78/200
# 20/20 [==============================] - 0s 4ms/step - loss: 13.5011 - mean_absolute_percentage_error: 6.0246
# Epoch 79/200
# 20/20 [==============================] - 0s 4ms/step - loss: 10.6195 - mean_absolute_percentage_error: 4.7341
# Epoch 80/200
# 20/20 [==============================] - 0s 4ms/step - loss: 9.4610 - mean_absolute_percentage_error: 4.1554
# Epoch 81/200
# 20/20 [==============================] - 0s 4ms/step - loss: 9.2824 - mean_absolute_percentage_error: 4.0727
# Epoch 82/200
# 20/20 [==============================] - 0s 4ms/step - loss: 15.9708 - mean_absolute_percentage_error: 7.0887
# Epoch 83/200
# 20/20 [==============================] - 0s 4ms/step - loss: 8.7919 - mean_absolute_percentage_error: 3.8736
# Epoch 84/200
# 20/20 [==============================] - 0s 4ms/step - loss: 8.3239 - mean_absolute_percentage_error: 3.6993
# Epoch 85/200
# 20/20 [==============================] - 0s 4ms/step - loss: 16.0253 - mean_absolute_percentage_error: 7.1296
# Epoch 86/200
# 20/20 [==============================] - 0s 4ms/step - loss: 16.4784 - mean_absolute_percentage_error: 7.3274
# Epoch 87/200
# 20/20 [==============================] - 0s 3ms/step - loss: 14.5948 - mean_absolute_percentage_error: 6.5911
# Epoch 88/200
# 20/20 [==============================] - 0s 4ms/step - loss: 13.3821 - mean_absolute_percentage_error: 5.9287
# Epoch 89/200
# 20/20 [==============================] - 0s 4ms/step - loss: 15.6719 - mean_absolute_percentage_error: 6.9221
# Epoch 90/200
# 20/20 [==============================] - 0s 4ms/step - loss: 8.2505 - mean_absolute_percentage_error: 3.6139
# Epoch 91/200
# 20/20 [==============================] - 0s 4ms/step - loss: 7.0061 - mean_absolute_percentage_error: 3.1121
# Epoch 92/200
# 20/20 [==============================] - 0s 4ms/step - loss: 7.8231 - mean_absolute_percentage_error: 3.4489
# Epoch 93/200
# 20/20 [==============================] - 0s 4ms/step - loss: 10.2921 - mean_absolute_percentage_error: 4.5719
# Epoch 94/200
# 20/20 [==============================] - 0s 3ms/step - loss: 8.4574 - mean_absolute_percentage_error: 3.7270
# Epoch 95/200
# 20/20 [==============================] - 0s 4ms/step - loss: 12.6112 - mean_absolute_percentage_error: 5.5100
# Epoch 96/200
# 20/20 [==============================] - 0s 4ms/step - loss: 7.6282 - mean_absolute_percentage_error: 3.4260
# Epoch 97/200
# 20/20 [==============================] - 0s 4ms/step - loss: 8.8116 - mean_absolute_percentage_error: 3.8723
# Epoch 98/200
# 20/20 [==============================] - 0s 4ms/step - loss: 11.1366 - mean_absolute_percentage_error: 4.9225
# Epoch 99/200
# 20/20 [==============================] - 0s 4ms/step - loss: 8.8723 - mean_absolute_percentage_error: 3.9205
# Epoch 100/200
# 20/20 [==============================] - 0s 4ms/step - loss: 13.1536 - mean_absolute_percentage_error: 5.8783
# Epoch 101/200
# 20/20 [==============================] - 0s 4ms/step - loss: 17.0289 - mean_absolute_percentage_error: 7.4427
# Epoch 102/200
# 20/20 [==============================] - 0s 4ms/step - loss: 11.0382 - mean_absolute_percentage_error: 4.8474
# Epoch 103/200
# 20/20 [==============================] - 0s 4ms/step - loss: 12.8617 - mean_absolute_percentage_error: 5.7200
# Epoch 104/200
# 20/20 [==============================] - 0s 3ms/step - loss: 11.1833 - mean_absolute_percentage_error: 4.9372
# Epoch 105/200
# 20/20 [==============================] - 0s 4ms/step - loss: 7.6973 - mean_absolute_percentage_error: 3.4110
# Epoch 106/200
# 20/20 [==============================] - 0s 4ms/step - loss: 10.6738 - mean_absolute_percentage_error: 4.7558
# Epoch 107/200
# 20/20 [==============================] - 0s 4ms/step - loss: 10.2826 - mean_absolute_percentage_error: 4.5149
# Epoch 108/200
# 20/20 [==============================] - 0s 4ms/step - loss: 13.1766 - mean_absolute_percentage_error: 5.8044
# Epoch 109/200
# 20/20 [==============================] - 0s 4ms/step - loss: 11.5802 - mean_absolute_percentage_error: 5.0837
# Epoch 110/200
# 20/20 [==============================] - 0s 4ms/step - loss: 15.9127 - mean_absolute_percentage_error: 7.0179
# Epoch 111/200
# 20/20 [==============================] - 0s 4ms/step - loss: 9.8383 - mean_absolute_percentage_error: 4.3189
# Epoch 112/200
# 20/20 [==============================] - 0s 4ms/step - loss: 14.0230 - mean_absolute_percentage_error: 6.1028
# Epoch 113/200
# 20/20 [==============================] - 0s 4ms/step - loss: 10.7341 - mean_absolute_percentage_error: 4.7406
# Epoch 114/200
# 20/20 [==============================] - 0s 4ms/step - loss: 11.6096 - mean_absolute_percentage_error: 5.1985
# Epoch 115/200
# 20/20 [==============================] - 0s 4ms/step - loss: 10.9611 - mean_absolute_percentage_error: 4.8038
# Epoch 116/200
# 20/20 [==============================] - 0s 4ms/step - loss: 7.2167 - mean_absolute_percentage_error: 3.1557
# Epoch 117/200
# 20/20 [==============================] - 0s 4ms/step - loss: 7.5192 - mean_absolute_percentage_error: 3.3152
# Epoch 118/200
# 20/20 [==============================] - 0s 4ms/step - loss: 7.5064 - mean_absolute_percentage_error: 3.3581
# Epoch 119/200
# 20/20 [==============================] - 0s 4ms/step - loss: 7.5862 - mean_absolute_percentage_error: 3.3294
# Epoch 120/200
# 20/20 [==============================] - 0s 4ms/step - loss: 8.1018 - mean_absolute_percentage_error: 3.5422
# Epoch 121/200
# 20/20 [==============================] - 0s 4ms/step - loss: 6.6643 - mean_absolute_percentage_error: 2.9600
# Epoch 122/200
# 20/20 [==============================] - 0s 4ms/step - loss: 7.1014 - mean_absolute_percentage_error: 3.1067
# Epoch 123/200
# 20/20 [==============================] - 0s 4ms/step - loss: 7.9837 - mean_absolute_percentage_error: 3.5083
# Epoch 124/200
# 20/20 [==============================] - 0s 4ms/step - loss: 6.9204 - mean_absolute_percentage_error: 3.0468
# Epoch 125/200
# 20/20 [==============================] - 0s 4ms/step - loss: 11.5558 - mean_absolute_percentage_error: 5.1401
# Epoch 126/200
# 20/20 [==============================] - 0s 4ms/step - loss: 8.8914 - mean_absolute_percentage_error: 3.9355
# Epoch 127/200
# 20/20 [==============================] - 0s 4ms/step - loss: 15.0150 - mean_absolute_percentage_error: 6.5523
# Epoch 128/200
# 20/20 [==============================] - 0s 4ms/step - loss: 7.8863 - mean_absolute_percentage_error: 3.5134
# Epoch 129/200
# 20/20 [==============================] - 0s 4ms/step - loss: 8.5778 - mean_absolute_percentage_error: 3.7852
# Epoch 130/200
# 20/20 [==============================] - 0s 4ms/step - loss: 16.0502 - mean_absolute_percentage_error: 7.1231
# Epoch 131/200
# 20/20 [==============================] - 0s 4ms/step - loss: 7.0163 - mean_absolute_percentage_error: 3.1381
# Epoch 132/200
# 20/20 [==============================] - 0s 4ms/step - loss: 7.1832 - mean_absolute_percentage_error: 3.2044
# Epoch 133/200
# 20/20 [==============================] - 0s 3ms/step - loss: 9.3178 - mean_absolute_percentage_error: 4.1000
# Epoch 134/200
# 20/20 [==============================] - 0s 4ms/step - loss: 8.7476 - mean_absolute_percentage_error: 3.9020
# Epoch 135/200
# 20/20 [==============================] - 0s 4ms/step - loss: 7.0316 - mean_absolute_percentage_error: 3.1907
# Epoch 136/200
# 20/20 [==============================] - 0s 4ms/step - loss: 6.2185 - mean_absolute_percentage_error: 2.7745
# Epoch 137/200
# 20/20 [==============================] - 0s 4ms/step - loss: 8.1039 - mean_absolute_percentage_error: 3.5927
# Epoch 138/200
# 20/20 [==============================] - 0s 4ms/step - loss: 7.3527 - mean_absolute_percentage_error: 3.2846
# Epoch 139/200
# 20/20 [==============================] - 0s 4ms/step - loss: 16.2872 - mean_absolute_percentage_error: 7.1546
# Epoch 140/200
# 20/20 [==============================] - 0s 4ms/step - loss: 7.1747 - mean_absolute_percentage_error: 3.1321
# Epoch 141/200
# 20/20 [==============================] - 0s 4ms/step - loss: 9.1892 - mean_absolute_percentage_error: 4.1212
# Epoch 142/200
# 20/20 [==============================] - 0s 6ms/step - loss: 12.3129 - mean_absolute_percentage_error: 5.4271
# Epoch 143/200
# 20/20 [==============================] - 0s 5ms/step - loss: 9.4778 - mean_absolute_percentage_error: 4.1853
# Epoch 144/200
# 20/20 [==============================] - 0s 5ms/step - loss: 14.8692 - mean_absolute_percentage_error: 6.5956
# Epoch 145/200
# 20/20 [==============================] - 0s 5ms/step - loss: 10.7158 - mean_absolute_percentage_error: 4.7793
# Epoch 146/200
# 20/20 [==============================] - 0s 5ms/step - loss: 7.6122 - mean_absolute_percentage_error: 3.3674
# Epoch 147/200
# 20/20 [==============================] - 0s 5ms/step - loss: 6.9351 - mean_absolute_percentage_error: 3.1043
# Epoch 148/200
# 20/20 [==============================] - 0s 5ms/step - loss: 13.1310 - mean_absolute_percentage_error: 5.8428
# Epoch 149/200
# 20/20 [==============================] - 0s 4ms/step - loss: 9.0630 - mean_absolute_percentage_error: 4.0590
# Epoch 150/200
# 20/20 [==============================] - 0s 5ms/step - loss: 10.4285 - mean_absolute_percentage_error: 4.6294
# Epoch 151/200
# 20/20 [==============================] - 0s 6ms/step - loss: 6.6247 - mean_absolute_percentage_error: 2.9351
# Epoch 152/200
# 20/20 [==============================] - 0s 5ms/step - loss: 8.5984 - mean_absolute_percentage_error: 3.8357
# Epoch 153/200
# 20/20 [==============================] - 0s 5ms/step - loss: 13.4415 - mean_absolute_percentage_error: 5.9600
# Epoch 154/200
# 20/20 [==============================] - 0s 5ms/step - loss: 13.8003 - mean_absolute_percentage_error: 6.0824
# Epoch 155/200
# 20/20 [==============================] - 0s 5ms/step - loss: 15.3756 - mean_absolute_percentage_error: 6.8082
# Epoch 156/200
# 20/20 [==============================] - 0s 5ms/step - loss: 11.5245 - mean_absolute_percentage_error: 5.1324
# Epoch 157/200
# 20/20 [==============================] - 0s 6ms/step - loss: 14.9626 - mean_absolute_percentage_error: 6.6104
# Epoch 158/200
# 20/20 [==============================] - 0s 5ms/step - loss: 10.4461 - mean_absolute_percentage_error: 4.6402
# Epoch 159/200
# 20/20 [==============================] - 0s 5ms/step - loss: 7.3259 - mean_absolute_percentage_error: 3.3065
# Epoch 160/200
# 20/20 [==============================] - 0s 5ms/step - loss: 10.4710 - mean_absolute_percentage_error: 4.7282
# Epoch 161/200
# 20/20 [==============================] - 0s 5ms/step - loss: 11.1259 - mean_absolute_percentage_error: 4.8603
# Epoch 162/200
# 20/20 [==============================] - 0s 5ms/step - loss: 8.5900 - mean_absolute_percentage_error: 3.8213
# Epoch 163/200
# 20/20 [==============================] - 0s 5ms/step - loss: 7.0144 - mean_absolute_percentage_error: 3.1908
# Epoch 164/200
# 20/20 [==============================] - 0s 5ms/step - loss: 11.9841 - mean_absolute_percentage_error: 5.4062
# Epoch 165/200
# 20/20 [==============================] - 0s 5ms/step - loss: 6.5526 - mean_absolute_percentage_error: 2.9430
# Epoch 166/200
# 20/20 [==============================] - 0s 5ms/step - loss: 6.6202 - mean_absolute_percentage_error: 2.9977
# Epoch 167/200
# 20/20 [==============================] - 0s 5ms/step - loss: 13.6790 - mean_absolute_percentage_error: 6.0479
# Epoch 168/200
# 20/20 [==============================] - 0s 5ms/step - loss: 13.3795 - mean_absolute_percentage_error: 5.9930
# Epoch 169/200
# 20/20 [==============================] - 0s 5ms/step - loss: 6.9794 - mean_absolute_percentage_error: 3.1556
# Epoch 170/200
# 20/20 [==============================] - 0s 5ms/step - loss: 6.3006 - mean_absolute_percentage_error: 2.8731
# Epoch 171/200
# 20/20 [==============================] - 0s 5ms/step - loss: 6.7460 - mean_absolute_percentage_error: 3.0257
# Epoch 172/200
# 20/20 [==============================] - 0s 5ms/step - loss: 6.5895 - mean_absolute_percentage_error: 2.9538
# Epoch 173/200
# 20/20 [==============================] - 0s 5ms/step - loss: 9.9935 - mean_absolute_percentage_error: 4.4667
# Epoch 174/200
# 20/20 [==============================] - 0s 5ms/step - loss: 11.2601 - mean_absolute_percentage_error: 5.0702
# Epoch 175/200
# 20/20 [==============================] - 0s 5ms/step - loss: 6.8129 - mean_absolute_percentage_error: 3.0134
# Epoch 176/200
# 20/20 [==============================] - 0s 5ms/step - loss: 11.2246 - mean_absolute_percentage_error: 4.9653
# Epoch 177/200
# 20/20 [==============================] - 0s 6ms/step - loss: 10.9756 - mean_absolute_percentage_error: 4.9158
# Epoch 178/200
# 20/20 [==============================] - 0s 5ms/step - loss: 6.5374 - mean_absolute_percentage_error: 2.9279
# Epoch 179/200
# 20/20 [==============================] - 0s 4ms/step - loss: 7.1900 - mean_absolute_percentage_error: 3.2162
# Epoch 180/200
# 20/20 [==============================] - 0s 4ms/step - loss: 7.6827 - mean_absolute_percentage_error: 3.3928
# Epoch 181/200
# 20/20 [==============================] - 0s 4ms/step - loss: 9.2978 - mean_absolute_percentage_error: 4.1825
# Epoch 182/200
# 20/20 [==============================] - 0s 4ms/step - loss: 6.7859 - mean_absolute_percentage_error: 3.0579
# Epoch 183/200
# 20/20 [==============================] - 0s 4ms/step - loss: 8.0501 - mean_absolute_percentage_error: 3.5724
# Epoch 184/200
# 20/20 [==============================] - 0s 4ms/step - loss: 6.8122 - mean_absolute_percentage_error: 3.0721
# Epoch 185/200
# 20/20 [==============================] - 0s 4ms/step - loss: 6.0482 - mean_absolute_percentage_error: 2.7311
# Epoch 186/200
# 20/20 [==============================] - 0s 4ms/step - loss: 7.3353 - mean_absolute_percentage_error: 3.3084
# Epoch 187/200
# 20/20 [==============================] - 0s 4ms/step - loss: 7.3231 - mean_absolute_percentage_error: 3.2751
# Epoch 188/200
# 20/20 [==============================] - 0s 4ms/step - loss: 6.1892 - mean_absolute_percentage_error: 2.7815
# Epoch 189/200
# 20/20 [==============================] - 0s 4ms/step - loss: 6.5714 - mean_absolute_percentage_error: 2.9238
# Epoch 190/200
# 20/20 [==============================] - 0s 4ms/step - loss: 6.4560 - mean_absolute_percentage_error: 2.8550
# Epoch 191/200
# 20/20 [==============================] - 0s 4ms/step - loss: 16.1322 - mean_absolute_percentage_error: 7.2574
# Epoch 192/200
# 20/20 [==============================] - 0s 4ms/step - loss: 6.7672 - mean_absolute_percentage_error: 3.0093
# Epoch 193/200
# 20/20 [==============================] - 0s 4ms/step - loss: 6.9084 - mean_absolute_percentage_error: 3.0976
# Epoch 194/200
# 20/20 [==============================] - 0s 4ms/step - loss: 6.0562 - mean_absolute_percentage_error: 2.7120
# Epoch 195/200
# 20/20 [==============================] - 0s 4ms/step - loss: 11.1119 - mean_absolute_percentage_error: 4.9738
# Epoch 196/200
# 20/20 [==============================] - 0s 4ms/step - loss: 11.4787 - mean_absolute_percentage_error: 5.1215
# Epoch 197/200
# 20/20 [==============================] - 0s 4ms/step - loss: 13.3366 - mean_absolute_percentage_error: 5.9107
# Epoch 198/200
# 20/20 [==============================] - 0s 4ms/step - loss: 13.9994 - mean_absolute_percentage_error: 6.2054
# Epoch 199/200
# 20/20 [==============================] - 0s 4ms/step - loss: 6.8661 - mean_absolute_percentage_error: 3.0833
# Epoch 200/200
# 20/20 [==============================] - 0s 4ms/step - loss: 5.5506 - mean_absolute_percentage_error: 2.5300

# %%
# Colab
Fmodel.save('Meta_DNN_trained_model.h5')
print('Model has been saved...')
# Out:
# Model has been saved...

# %%
# 7.4 Restore the saved model for testing
#ANN_model=keras.models.load_model('D:/data_analysis/PyExport/Rainfall_forecast_ANN_trained_model.h5')
# Colab
ANN_model=keras.models.load_model('Meta_DNN_trained_model.h5')
print('Model successfully loaded...')
# Out:
# Model successfully loaded...

# %% [markdown]
# # 8. Testing

# %%
# X test
x_forecast_test=Forecast_test_data.drop(['Date','Close'],axis=1).copy()
# Y test
y_forecast_test=Forecast_test_data['Close'].copy()

# %%
# 8.1 Make prediction 
prediction=np.round((ANN_model.predict_on_batch(x_forecast_test)),2)
pred_values=[]
for i in range(0,len(prediction)):
    value=prediction[i][0]
    pred_values.append(value)

# %%
Results=pd.DataFrame({'Date':Forecast_test_data['Date'],'Close_true':Forecast_test_data['Close'],'Predict':pred_values})
Results['abs Error']=np.abs(Results['Close_true']-Results['Predict'])
Results
# Out:
#             Date  Close_true     Predict  abs Error
# 1257  2022-05-24  181.279999  201.330002  20.050003
# 1258  2022-05-25  183.830002  185.690002   1.860000
# 1259  2022-05-26  191.630005  189.729996   1.900009
# 1260  2022-05-27  195.130005  197.669998   2.539993
# 1261  2022-05-31  193.639999  200.259995   6.619996
# ...          ...         ...         ...        ...
# 1502  2023-05-16  238.820007  244.820007   6.000000
# 1503  2023-05-17  242.490005  244.139999   1.649994
# 1504  2023-05-18  246.850006  248.190002   1.339996
# 1505  2023-05-19  245.639999  252.229996   6.589997
# 1506  2023-05-22  248.320007  250.639999   2.319992
#
# [250 rows x 4 columns]

# %%
# 8.2 Calculating the mertics
MAE=mean_absolute_error(y_forecast_test,pred_values)
MSE=mean_squared_error(y_forecast_test,pred_values,squared=True)
RMSE=mean_squared_error(y_forecast_test,pred_values,squared=False)
MAPE=mean_absolute_percentage_error(y_forecast_test,pred_values)
SMAPE=SMAPE_calulate(y_forecast_test,pred_values)
RAE=RAE_calculate(y_forecast_test,pred_values)
MRAE=MRAE_calculate(y_forecast_test,pred_values)
MdRAE=MdRAE_calculate(y_forecast_test,pred_values)
RSE=RSE_calculate(y_forecast_test,pred_values,Root=False)
RRSE=RSE_calculate(y_forecast_test,pred_values,Root=True)

print('MAE:',round(MAE,3))
print('MSE:',round(MSE,3))
print('RMSE:',round(RMSE,3))
print('MAPE:',round(MAPE*100,3),'%')
print('SMAPE:',round(SMAPE,3),'%')
print('RAE:',round(RAE,3))
print('MRAE:',MRAE)
print('MdRAE:',round(MdRAE[0],3),'bench:',round(MdRAE[1],3))
print('RSE:',round(RSE,3))
print('RRSE:',round(RRSE,3))
# Out:
# MAE: 12.159
# MSE: 268.627
# RMSE: 16.39
# MAPE: 9.337 %
# SMAPE: 8.442 %
# RAE: 0.4
# MRAE: 0.0016000850805604218
# MdRAE: 0.501 bench: 163.447
# RSE: 0.19
# RRSE: 0.436

# %% [markdown]
# #  Plot for comparing true value & predicted value

# %%
# Plot Y and its corresponding date
# Figure setting
plt.figure(figsize=(24,8),dpi=300)
plt.title('True value vs Predict value',weight='bold',fontsize=24)
plt.xlabel('Date',fontsize=18,weight='bold')
plt.ylabel('Closing Price',fontsize=18,weight='bold')

# Comparison of actual value and predicted value according to Date
plt.plot(clean_df.iloc[189:,0],clean_df.iloc[189:,1],marker='o',color='blue',label='Actual')
plt.plot(Results['Date'],Results['Predict'],marker='o',color='red',label='Forecast')

# Set the axis
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

# Set legends
plt.legend(loc=4,fontsize=20)

plt.show()

# %% [markdown]
# # Actual by predicted plot

# %%
# Lock the scale of axis by Close_true
max_value=390
min_value=0

# Figure setting
plt.figure(figsize=(10,10),dpi=300)
plt.title('Actual by predicted plot',weight='bold',fontsize=24)
plt.xlabel('Actual (Close-true)',fontsize=18,weight='bold')
plt.ylabel('Forecast',fontsize=18,weight='bold')

# Perfect model reference line
plt.plot([min_value,max_value], [min_value,max_value], linestyle='--',color='red')

# Actual by predicted plot
plt.scatter(Results.iloc[:,1],Results.iloc[:,2],marker='.',color='blue')

# Set the axis
plt.ylim(0-5,max_value)
plt.xlim(0-5,max_value)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()
